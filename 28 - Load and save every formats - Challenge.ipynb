# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Load & save every formats

# %% [markdown]
# ## CSV extension can be misleading

# %% [markdown]
# As a Data Analyst at Daco, someone from marketing team asks you to help him to open `daco_orders_samples_other_format.csv`. Can you do that?

# %% [markdown]
# 1) Import [daco_orders_samples_other_format.csv](https://drive.google.com/file/d/1kebq3jCE-S1OtsJFInkaGtD32Wn3ENTJ/view?usp=sharing) in colab and load it in a `df_orders` variable.

# %% [markdown]
# 2) Is there something wrong with this data ?
# Print `df_orders` and find out in [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) how to solve the issue.
#
# Use StackOverflow to help you.

# %% [markdown]
# 3) Create a csv file with a comma as separator to help business teams.

# %% [markdown]
# Yes ! you did it !

# %% [markdown]
# ## Dealing with json files

# %% [markdown]
# 1) Execute the following cell to initialize dictionary `d`

# %%
d = {"firstname": "lionel",
     "lastname": "messi",
     "job": "football player"}

# %% [markdown]
# 2) Create a file `players.json` from `d`. Verify in Colab.

# %% [markdown]
# 3) Open `players.json` file to add a new key "nationality". Lionel Messi is Argentine. Save the result to the same file name. Check your file.

# %% [markdown]
# ## Working with Excel files

# %% [markdown]
# You are owner of mutliple Condor sport shops and your are doing your accountability on Excel.

# %% [markdown]
# 1) Download [excel file](https://docs.google.com/spreadsheets/d/1MaNvf6ojPu12gP5aMhT6vrIQclBLDcbE/edit?usp=sharing&ouid=101856744232579947807&rtpof=true&sd=true) and explore it.
#
# If you don't have Excel on your computer, drag and drop this file to your own drive to open it with google sheets.
#
# How many sheets?
# What kind of data can you find?

# %% [markdown]
# 2) Import excel file in your colab.
# Open data from first sheet with pandas in a `df_sales_store_1` variable.

# %% [markdown]
# 3) How can you list all sheets in excel file with pandas ?

# %% [markdown]
# 4) Load data from second sheet in `df_sales_store_2` variable.
#
# Hint: read carefully documentation or stackoverflow to do it

# %% [markdown]
# 5) Add in each dataframe the `store_id` (id = 1 for store_1 and id = 2 for store_2) and concatenate the two dataframes into a single one `df_sales`.

# %% [markdown]
# 6) Write a code Python to create a new sheet "All" and save `df_sales` in it.

# %% [markdown]
# ## Working with unidentified format

# %% [markdown]
# Someone from the team found a file named [`secret.pkl`](https://drive.google.com/file/d/1_oia73SoCZtZFsGbDrsffkSfdaj2Gt5O/view?usp=sharing).
#
# Can you help him to open it and find what's in there ?

# %% [markdown]
# Note you can use pandas when your serializing object is a DataFrame.
